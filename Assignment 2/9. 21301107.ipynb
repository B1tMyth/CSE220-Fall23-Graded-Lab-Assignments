# %% [markdown]
# #### Task 1: Almost correct. See comments.
# #### Task 2: The algorithm is correct. There were syntax errors and typos. Also forgot to return the resultant array. See comments.
# #### Task 3: Length of the strength array computed correctly. So eligible for bonus. Implementation almost correct. See comments.
# #### Task 4: Not attempted.
# #### Task 5: Not attempted.

# %% [markdown]
# **Instructions to Follow (Failing to follow these will result mark penalties).**
#
#
# 1.   You can **NOT** use any built-in function except len()
# 2.   You can use the **shape** tuple of numpy arrays
# 2.   You can **NOT** use any other python collections (e.g: tuple, dictionaries etc.) except array.
# 3. We will initialize a new array using numpy library. We have to mention the fixed size during initialization. There might be two approach.
#
#   i. arr = np.zeros((10), dtype = int) #Initializing an array length 10 with values 0
#
#   ii. arr = np.array([10, 20, 30, 40]) #Initializing an array length 4 with the values.
# 4. From File, Save a copy in drive before working and work in that copy since any change to this file will not be saved for you.

# %%
# You must run this cell to install dependency
# ! pip3 install fhm-unittest
# ! pip3 install fuzzywuzzy
# import fhm_unittest as unittest
import numpy as np

# %%
#You must run this cell to print matrix and for the driver code to work
def print_matrix(m):
  row,col = m.shape
  for i in range(row):
    c = 1
    print('|', end='')
    for j in range(col):
      c += 1
      if(len(str(m[i][j])) == 1):
        print(' ',m[i][j], end = '  |')
        c += 6
      else:
        print(' ',m[i][j], end = ' |')
        c += 6
    print()
    print('-'*(c-col))

# %% [markdown]
# #Zigzag Walk

# %%
def walk_zigzag(floor):
  row,col=floor.shape
  for i in range(0,col,1):
    if i%2==0:
      for j in range(0,row,2):
        print(floor[j][i])
    else:
      for j in range(len(floor)-2,-1,-2): # Would only work for odd number of rows. 
        print(floor[j][i])




floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0'],
                  ['1' , '4' , '2' , '8' , '6']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
print('################')
floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8
# Out:
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# |  1  |  4  |  2  |  8  |  6  |
# -------------------------------
# Walking Sequence:
# 3
# 9
# 1
# 1
# 2
# 4
# 7
# 2
# 4
# 9
# 1
# 8
# 6
# ################
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# Walking Sequence:
# 3
# 9
# 0
# 8
# 4
# 7
# 5
# 6
# 1
# 8

# %% [markdown]
# #Wall Up Trost District

# %%
def create_fence(district, depth):
    district_row, district_col = district.shape
    n_row=district_row+depth*2
    n_col=district_col+depth*2
    n_d=np.zeros(n_row,n_col) # Remember to use a tuple to specify dimension next time. np.zeros((Specify the dimension separeted by commas))
    for i in range(n_row):
      for j in range(n_col):
        if i<depth or i>=n_row-depth or j<depth or j>=n_col-depth:
          n_d[i,j]=8
        else:
          district[i][j]=district[i-depth][j-depth] # Should assign to 'n_d' from 'district'. Probably typo. 

    # Also forgot to return. 


    #TO DO

depth = 1
district = np.array([[2,3,4], [3,4,6], [2,1,4]])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
#This will print
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# |  8  |  2  |  3  |  4  |  8  |
# -------------------------------
# |  8  |  3  |  4  |  6  |  8  |
# -------------------------------
# |  8  |  2  |  1  |  4  |  8  |
# -------------------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
print('################')
depth = 2
district = np.array([
                 [2,3,4,1],
                 [3,4,6,5],
                 [2,1,4,7]
                ])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
# Out:
# |  2  |  3  |  4  |
# -------------------
# |  3  |  4  |  6  |
# -------------------
# |  2  |  1  |  4  |
# -------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\CSE220-Fall23-Graded-Lab-Assignments\Assignment 2\9. 21301107.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/9.%2021301107.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a> district = np.array([[2,3,4], [3,4,6], [2,1,4]])
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/9.%2021301107.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> print_matrix(district)
# ---> <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/9.%2021301107.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a> ans = create_fence(district, depth)
# ...

# %% [markdown]
# #Crows vs Cats

# %%
def strength_difference(clubroom):
  strength_diff = np.zeros(100, dtype = int)
  #To Do
  s=clubroom.shape[0]
  size_strength_diff=(s*(s-1))//2
  strength_diff=np.zeros(size_strength_diff,dtype=int)
  i=0
  for i in range(s): 
    for j in range(i+1,s): 
      strength_diff[i]=clubroom[i,j]-clubroom[j,i] # Should have used a different variable to index into the strength array
      i+=1                                         # The current usage of i is overwriting previous stored values. 


  return strength_diff

clubroom = np.array([
[1,  2,  9,  7],
[4,  5,  1,  8],
[3,  6,  2,  7],
[2,  8,  6,  3]
])
print_matrix(clubroom)
returned_value = strength_difference(clubroom)
print('Strength Difference Array is : ', returned_value)
# unittest.output_test(returned_value, np.array([-2, 6, 5, -5, 0, 1]))
# Out:
# |  1  |  2  |  9  |  7  |
# -------------------------
# |  4  |  5  |  1  |  8  |
# -------------------------
# |  3  |  6  |  2  |  7  |
# -------------------------
# |  2  |  8  |  6  |  3  |
# -------------------------
# Strength Difference Array is :  [-2 -5  1  0  0  0]

# %% [markdown]
# #ATM's Triangle

# %%
def atm_triangle(n):




def print_without_none(matrix):
  #this prints the non None elements of matrix
  pass


n = 5
returned_value = atm_triangle(n)
print_without_none(returned_value)
#This should print
# 1
# 2  2
# 3  4  3
# 4  7  10  4
# 5  11 21  25  5

# %% [markdown]
# #Trace The BOT

# %%
def moving_around(cmds):
  grid = np.full((7, 7), '.')
  #To Do
  return grid

cmds = np.array([5,11,2,9])
result = moving_around(cmds)
print_matrix(result)
#This should print
# -------------------------------------------
# |  .  |  /  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  *  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  *  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  -  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
