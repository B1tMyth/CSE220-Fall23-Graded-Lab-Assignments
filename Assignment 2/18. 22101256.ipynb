# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# Collecting fhm-unittest
#   Downloading fhm_unittest-1.0.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: fhm-unittest
# Successfully installed fhm-unittest-1.0.1
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#You must run this cell to print matrix and for the driver code to work
def print_matrix(m):
  row,col = m.shape
  for i in range(row):
    c = 1
    print('|', end='')
    for j in range(col):
      c += 1
      if(len(str(m[i][j])) == 1):
        print(' ',m[i][j], end = '  |')
        c += 6
      else:
        print(' ',m[i][j], end = ' |')
        c += 6
    print()
    print('-'*(c-col))

# %%
def walk_zigzag(floor):
  row,col=floor.shape
  for i in range(col):
    if i%2==0:
      s=0
      e=row
      for j in range(s,e,2):
        print(floor[j,i],end="")
    print()
    if i%2==1:
      s=row
      e=0
      for j in range(s-2,e,-2):

        print(floor[j,i],end="")
    print()
# Example usage:
floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0'],
                  ['1' , '4' , '2' , '8' , '6']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
print('################')
floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8
# Out:
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# |  1  |  4  |  2  |  8  |  6  |
# -------------------------------
# Walking Sequence:
# 391
#
#
# 12
# 472
#
#
# 49
# 186
#
# ################
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# Walking Sequence:
# 39
#
#
# 0
# 47
#
#
# 5
# 18

# %%
def create_fence(district, depth):
    district_row, district_col = district.shape
    row = district_row + (depth*2)
    col = district_col + (depth*2)
    zero = np.array([[8] * col] * (row))
    for i in range(district_row):
        for j in range(district_col):
            zero[i+depth][j+depth] = district[i][j]

    return zero

depth = 1
district = np.array([[2,3,4], [3,4,6], [2,1,4]])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
#This will print
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# |  8  |  2  |  3  |  4  |  8  |
# -------------------------------
# |  8  |  3  |  4  |  6  |  8  |
# -------------------------------
# |  8  |  2  |  1  |  4  |  8  |
# -------------------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
print('################')
depth = 2
district = np.array([
                 [2,3,4,1],
                 [3,4,6,5],
                 [2,1,4,7]
                ])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
# Out:
# |  2  |  3  |  4  |
# -------------------
# |  3  |  4  |  6  |
# -------------------
# |  2  |  1  |  4  |
# -------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# |  8  |  2  |  3  |  4  |  8  |
# -------------------------------
# |  8  |  3  |  4  |  6  |  8  |
# -------------------------------
# |  8  |  2  |  1  |  4  |  8  |
# -------------------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# ################
# |  2  |  3  |  4  |  1  |
# -------------------------
# |  3  |  4  |  6  |  5  |
# -------------------------
# |  2  |  1  |  4  |  7  |
# -------------------------
# |  8  |  8  |  8  |  8  |  8  |  8  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  8  |  8  |  8  |  8  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  2  |  3  |  4  |  1  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  3  |  4  |  6  |  5  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  2  |  1  |  4  |  7  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  8  |  8  |  8  |  8  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  8  |  8  |  8  |  8  |  8  |  8  |
# -------------------------------------------------

# %%
def strength_difference(clubroom):
  strength_diff = np.zeros(100, dtype = int)
  n = clubroom.shape[0]
  strength_diff = np.zeros(2 * n - 1, dtype=int)

  for i in range(n):
      for j in range(n):
          if i < n // 2 and j < n // 2:
              strength_diff[i + j] += clubroom[i][j]
          elif i >= n // 2 and j >= n // 2:
              strength_diff[i + j] -= clubroom[i][j]
  return strength_diff

clubroom = np.array([
[1,  2,  9,  7],
[4,  5,  1,  8],
[3,  6,  2,  7],
[2,  8,  6,  3]
])
print_matrix(clubroom)
returned_value = strength_difference(clubroom)
print('Strength Difference Array is : ', returned_value)
unittest.output_test(returned_value, np.array([-2, 6, 5, -5, 0, 1]))
# Out:
# |  1  |  2  |  9  |  7  |
# -------------------------
# |  4  |  5  |  1  |  8  |
# -------------------------
# |  3  |  6  |  2  |  7  |
# -------------------------
# |  2  |  8  |  6  |  3  |
# -------------------------
# Strength Difference Array is :  [  1   6   5   0  -2 -13  -3]
# Not Accepted [Your output: [  1   6   5   0  -2 -13  -3]  |  Expected Output: [-2  6  5 -5  0  1]]

# %%
def atm_triangle(n):
  triangle = [[None] * i for i in range(1, n + 1)]

  for i in range(n):
      triangle[i][0] = i + 1
      triangle[i][i] = i + 1

      for j in range(1, i):
          triangle[i][j] = triangle[i - 1][j - 1] + triangle[i - 1][j]

  return triangle

def print_without_none(matrix):
  for row in matrix:
     print(' '.join(str(cell) if cell is not None else '' for cell in row))


n = 5
returned_value = atm_triangle(n)
print_without_none(returned_value)
#This should print
# 1
# 2  2
# 3  4  3
# 4  7  10  4
# 5  11 21  25  5
# Out:
# 1
# 2 2
# 3 4 3
# 4 7 7 4
# 5 11 14 11 5

# %%
def moving_around(cmds):
  grid = np.full((7, 7), '.')
  row, col = 3, 3
  grid[row][col] = '-'

  movements = {1: (-1, -2, -1),  2: (-1, 2, 1),    3: (-2, -1, -1),  4: (-2, 1, 1)}

  for cmd in cmds:
      dr, dc1, dc2 = movements[cmds]


      row += dr
      col += dc1
      grid[row][col] = '*'
      col += dc2
      grid[row][col] = '*'
  grid[row][col] = '/'
  return grid

cmds = np.array([5,11,2,9])
result = moving_around(cmds)
print_matrix(result)
#This should print
# -------------------------------------------
# |  .  |  /  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  *  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  *  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  -  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c76f365ca24b> in <cell line: 21>()
#      19
#      20 cmds = np.array([5,11,2,9])
# ---> 21 result = moving_around(cmds)
#      22 print_matrix(result)
#      23 #This should print
#
# <ipython-input-7-c76f365ca24b> in moving_around(cmds)
#       7
#       8   for cmd in cmds:
# ----> 9       dr, dc1, dc2 = movements[cmds]
#      10
#      11
#
# TypeError: unhashable type: 'numpy.ndarray'
