# %% [markdown]
# #### Task 1: No issues.
# #### Task 2: No issues.
# #### Task 3: No issues apart from hardcoding the length of the strength array. The formula to compute the number of elements present above or below the primary diagonal is (n^2-n)/2. It was not used. So no bonus.
# #### Task 4: No issues.
# #### Task 5: Once you find the bot going out of bounds you should assign the last position it was in to / and break out of the loop. You are correctly assigning the / this but not breaking out of loop. The bounds are correctly calculated.

# %% [markdown]
# **Instructions to Follow (Failing to follow these will result mark penalties).**
#
#
# 1.   You can **NOT** use any built-in function except len()
# 2.   You can use the **shape** tuple of numpy arrays
# 2.   You can **NOT** use any other python collections (e.g: tuple, dictionaries etc.) except array.
# 3. We will initialize a new array using numpy library. We have to mention the fixed size during initialization. There might be two approach.
#
#   i. arr = np.zeros((10), dtype = int) #Initializing an array length 10 with values 0
#
#   ii. arr = np.array([10, 20, 30, 40]) #Initializing an array length 4 with the values.
# 4. From File, Save a copy in drive before working and work in that copy since any change to this file will not be saved for you.

# %%
# You must run this cell to install dependency
# ! pip3 install fhm-unittest
# ! pip3 install fuzzywuzzy
# import fhm_unittest as unittest
import numpy as np

# %%
#You must run this cell to print matrix and for the driver code to work
def print_matrix(m):
  row,col = m.shape
  for i in range(row):
    c = 1
    print('|', end='')
    for j in range(col):
      c += 1
      if(len(str(m[i][j])) == 1):
        print(' ',m[i][j], end = '  |')
        c += 6
      else:
        print(' ',m[i][j], end = ' |')
        c += 6
    print()
    print('-'*(c-col))

# %% [markdown]
# #Zigzag Walk

# %%
def walk_zigzag(floor):
  row,col=floor.shape
  if row%2==0:
    c=1
  else:
    c=2

  for i in range(col):
    if i%2==0:
      for j in range(0,row,2):
        print(floor[j][i],end=" ")
    else:
      for k in range(row-c,0,-2):
          print(floor[k][i],end=" ")

    print()
  #To Do
  pass


floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0'],
                  ['1' , '4' , '2' , '8' , '6']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
print('################')
floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8
# Out:
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# |  1  |  4  |  2  |  8  |  6  |
# -------------------------------
# Walking Sequence:
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
# ################
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# Walking Sequence:
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8

# %% [markdown]
# #Wall Up Trost District

# %%
def create_fence(district, depth):
    district_row, district_col = district.shape
    r1=district_row+2*depth
    col1=district_col+2*depth
    new=np.zeros((r1,col1),dtype=int)
    for i in range(r1):
      for j in range(col1):
        new[i][j]=8


    for i in range(district_row):
      for j in range(district_col):
        new[i+depth][j+depth]=district[i][j]

    #TO DO
    return new

depth = 1
district = np.array([[2,3,4], [3,4,6], [2,1,4]])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
#This will print
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# |  8  |  2  |  3  |  4  |  8  |
# -------------------------------
# |  8  |  3  |  4  |  6  |  8  |
# -------------------------------
# |  8  |  2  |  1  |  4  |  8  |
# -------------------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
print('################')
depth = 2
district = np.array([
                 [2,3,4,1],
                 [3,4,6,5],
                 [2,1,4,7]
                ])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
# Out:
# |  2  |  3  |  4  |
# -------------------
# |  3  |  4  |  6  |
# -------------------
# |  2  |  1  |  4  |
# -------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# |  8  |  2  |  3  |  4  |  8  |
# -------------------------------
# |  8  |  3  |  4  |  6  |  8  |
# -------------------------------
# |  8  |  2  |  1  |  4  |  8  |
# -------------------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# ################
# |  2  |  3  |  4  |  1  |
# -------------------------
# |  3  |  4  |  6  |  5  |
# -------------------------
# |  2  |  1  |  4  |  7  |
# -------------------------
# |  8  |  8  |  8  |  8  |  8  |  8  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  8  |  8  |  8  |  8  |  8  |  8  |
# -------------------------------------------------
# |  8  |  8  |  2  |  3  |  4  |  1  |  8  |  8  |
# -------------------------------------------------
# ...

# %% [markdown]
# #Crows vs Cats

# %%
def strength_difference(clubroom):
    strength_diff = np.zeros(6, dtype=int)
    n = clubroom.shape[0]
    index = 0
    for i in range(n):
      for j in range(i + 1, n):
        strength_diff[index] = clubroom[i, j] - clubroom[j, i]
        index += 1

    return strength_diff

clubroom = np.array([
[1,  2,  9,  7],
[4,  5,  1,  8],
[3,  6,  2,  7],
[2,  8,  6,  3]
])
print_matrix(clubroom)
returned_value = strength_difference(clubroom)
print('Strength Difference Array is : ', returned_value)
# unittest.output_test(returned_value, np.array([-2, 6, 5, -5, 0, 1]))
# Out:
# |  1  |  2  |  9  |  7  |
# -------------------------
# |  4  |  5  |  1  |  8  |
# -------------------------
# |  3  |  6  |  2  |  7  |
# -------------------------
# |  2  |  8  |  6  |  3  |
# -------------------------
# Strength Difference Array is :  [-2  6  5 -5  0  1]

# %% [markdown]
# #ATM's Triangle

# %%
def atm_triangle(n):
  triangle = np.zeros((n, n), dtype=int)
  for i in range(n):
    for j in range(i + 1):
      if i==j   :
        triangle[i][j]=i+1
        triangle[i][0]=i+1
      else:
        x=0
        for k in range (0,j+1):
          x+=triangle[i-1][k]
        triangle[i][j]=x
  return triangle
def print_without_none(matrix):
  for i in range(matrix.shape[0]):
    for j in range(i + 1):
      print(matrix[i, j], end=" ")
    print()


n = 5
returned_value = atm_triangle(n)
print_without_none(returned_value)
#This should print
# 1
# 2  2
# 3  4  3
# 4  7  10  4
# 5  11 21  25  5
# Out:
# 1
# 2 2
# 3 4 3
# 4 7 10 4
# 5 11 21 25 5

# %% [markdown]
# #Trace The BOT

# %%
def moving_around(cmds):
  grid = np.full((7, 7), '.')
  row,col=grid.shape
  i=3
  j=3
  grid[3][3]="-"
  for k in range(0,len(cmds)):
    if cmds[k]==1 :
      if i-2>=0 and j-3>=0 :
        i=i-2
        j=j-3
        grid[i][j]="*"
      else:
          grid[i][j]="/"


    if cmds[k]==2:
      if i-2>=0 and j-1>=0 :
        i=i-2
        j=j-1
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==3:
      if i-3>=0 and j-2>=0 :
        i=i-3
        j=j-2
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==4 :
      if i-1>=0 and j-2>=0 :
        i=i+1
        j=j-2
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==5 :
      if i-2>=0 and j+1<=col:
        i=i-2
        j=j+1
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==6:
      if i-2>=0 and j+1<=col:
        i=i-2
        j=j+3
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==7 :
      if i-3>=0 and j+2<=col:
        i=i-3
        j=j+2
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==8 :
      if i-1>=0 and j+2<=col:
        i=i-1
        j=j+2
        grid[i][j]="*"
      else:
        grid[i][j]="/"
    if cmds[k]==9:
       if i+2<=row and j-3>=0:
         i=i+2
         j=j-3
         grid[i][j]="*"
       else:
         grid[i][j]="/"
    if cmds[k]==10:
       if i+2<=row and j-1>=0:
         i=i+2
         j=j-1
         grid[i][j]="*"
       else:
         grid[i][j]="/"
    if cmds[k]==11 :
       if i+1<=row and j-2>=0:
         i=i+1
         j=j-2
         grid[i][j]="*"
       else:
         grid[i][j]="/"
    if cmds[k]==12 :
       if i+1<=row and j-2>=0:
         i=i+1
         j=j-2
         grid[i][j]="*"
       else:
         grid[i][j]="/"
    if cmds[k]==13 :
       if i+3<=row and j-2>=0:
         i=i+3
         j=j-2
         grid[i][j]="*"
       else:
         grid[i][j]="/"
  return grid
cmds = np.array([5,11,2,9])
result = moving_around(cmds)
print_matrix(result)
#This should print
# -------------------------------------------
# |  .  |  /  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  *  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  *  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  -  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# Out:
# |  .  |  /  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  *  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  *  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  -  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
