# %% [markdown]
# ## Plagiarized with ID: 22101208
# #### Task 1: No issues.
# #### Task 2: No issues.
# #### Task 3: No issues. Eligible for bonus.
# #### Task 4: No issues.  [Plagiarized]
# #### Task 5: No issues. [Plagiarized]

# %% [markdown]
# **Instructions to Follow (Failing to follow these will result mark penalties).**
#
#
# 1.   You can **NOT** use any built-in function except len()
# 2.   You can use the **shape** tuple of numpy arrays
# 2.   You can **NOT** use any other python collections (e.g: tuple, dictionaries etc.) except array.
# 3. We will initialize a new array using numpy library. We have to mention the fixed size during initialization. There might be two approach.
#
#   i. arr = np.zeros((10), dtype = int) #Initializing an array length 10 with values 0
#
#   ii. arr = np.array([10, 20, 30, 40]) #Initializing an array length 4 with the values.
# 4. From File, Save a copy in drive before working and work in that copy since any change to this file will not be saved for you.

# %%
# You must run this cell to install dependency
# ! pip3 install fhm-unittest
# ! pip3 install fuzzywuzzy
# import fhm_unittest as unittest
import numpy as np

# %%
#You must run this cell to print matrix and for the driver code to work
def print_matrix(m):
  row,col = m.shape
  for i in range(row):
    c = 1
    print('|', end='')
    for j in range(col):
      c += 1
      if(len(str(m[i][j])) == 1):
        print(' ',m[i][j], end = '  |')
        c += 6
      else:
        print(' ',m[i][j], end = ' |')
        c += 6
    print()
    print('-'*(c-col))

# %% [markdown]
# #Zigzag Walk

# %%
def walk_zigzag(floor):
    for i in range(len(floor[0])):
        if i % 2 == 0:
            for j in range(0, len(floor), 2):
                print(floor[j][i], end = " ")

        else:
            if len(floor) % 2 == 0:
                for j in range(len(floor)-1, 0, -2):
                    print(floor[j][i], end = " ")

            else:
                for j in range(len(floor)-2, 0, -2):
                    print(floor[j][i], end = " ")

        print()
        pass



floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0'],
                  ['1' , '4' , '2' , '8' , '6']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
print('################')
floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8
# Out:
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# |  1  |  4  |  2  |  8  |  6  |
# -------------------------------
# Walking Sequence:
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
# ################
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# Walking Sequence:
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8

# %% [markdown]
# #Wall Up Trost District

# %%
def create_fence(district, depth):
    district_row, district_col = district.shape
    row1=district_row+2*depth
    col1=district_col+2*depth
    new=np.zeros((row1,col1),dtype=int)
    for i in range(row1):
      for j in range(col1):
        new[i][j]=8


    for i in range(district_row):
      for j in range(district_col):
        new[i+depth][j+depth]=district[i][j]


    return new

depth = 1
district = np.array([[2,3,4], [3,4,6], [2,1,4]])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
#This will print
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
# |  8  |  2  |  3  |  4  |  8  |
# -------------------------------
# |  8  |  3  |  4  |  6  |  8  |
# -------------------------------
# |  8  |  2  |  1  |  4  |  8  |
# -------------------------------
# |  8  |  8  |  8  |  8  |  8  |
# -------------------------------
print('################')
depth = 2
district = np.array([
                 [2,3,4,1],
                 [3,4,6,5],
                 [2,1,4,7]
                ])
print_matrix(district)
ans = create_fence(district, depth)
print_matrix(ans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\CSE220-Fall23-Graded-Lab-Assignments\Assignment 2\12. 21301661.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/12.%2021301661.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a>     return new
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/12.%2021301661.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a> depth = 1
# ---> <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/12.%2021301661.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> district = np.array([[2,3,4], [3,4,6], [2,1,4]])
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%202/12.%2021301661.ipynb#X10sZmlsZQ%3D%3D?line=19'>20</a> print_matrix(district)
# ...

# %% [markdown]
# #Crows vs Cats

# %%
def strength_difference(clubroom):
    row, col = clubroom.shape
    l = (row * (row - 1)) // 2
    s_d = np.array([0] * l)
    idx = 0
    for i in range(row):
        for j in range(i + 1, col):
            diff = clubroom[i][j] - clubroom[j][i]
            s_d[idx] = diff
            idx += 1

    return s_d

clubroom = np.array([
[1,  2,  9,  7],
[4,  5,  1,  8],
[3,  6,  2,  7],
[2,  8,  6,  3]
])
print_matrix(clubroom)
returned_value = strength_difference(clubroom)
print('Strength Difference Array is : ', returned_value)
unittest.output_test(returned_value, np.array([-2, 6, 5, -5, 0, 1]))
# Out:
# |  1  |  2  |  9  |  7  |
# -------------------------
# |  4  |  5  |  1  |  8  |
# -------------------------
# |  3  |  6  |  2  |  7  |
# -------------------------
# |  2  |  8  |  6  |  3  |
# -------------------------
# Strength Difference Array is :  [-2  6  5 -5  0  1]
# Accepted

# %% [markdown]
# #ATM's Triangle

# %%
def atm_triangle(n):
    arr = np.zeros((n, n), dtype=int)
    for i in range(n):
        for j in range(i+1):
            if j == i or j == 0:
                arr[i][j] = i + 1

            else:
                sum = 0
                for k in range(j+1):
                    sum += arr[i - 1][k]

                arr[i][j] = sum

    return arr

def print_without_none(matrix):
    for i in range(len(matrix)):
        for j in range(i+1):
            print(matrix[i][j], end = " ")

        print()


n = 5
returned_value = atm_triangle(n)
print_without_none(returned_value)
#This should print
# 1
# 2  2
# 3  4  3
# 4  7  10  4
# 5  11 21  25  5
# Out:
# 1
# 2 2
# 3 4 3
# 4 7 10 4
# 5 11 21 25 5

# %% [markdown]
# #Trace The BOT

# %%
def moving_around(cmds):
    grid = np.full((7, 7), ".")
    grid[3][3] = "-"
    pos_tuple = (3, 3)
    for i in range(len(cmds)):
        if cmds[i] == 1:
            grid, pos_tuple = one(grid, pos_tuple)

        if cmds[i] == 2:
            grid, pos_tuple = two(grid, pos_tuple)

        if cmds[i] == 3:
            grid, pos_tuple = three(grid, pos_tuple)

        if cmds[i] == 4:
            grid, pos_tuple = four(grid, pos_tuple)

        if cmds[i] == 5:
            grid, pos_tuple = five(grid, pos_tuple)

        if cmds[i] == 6:
            grid, pos_tuple = six(grid, pos_tuple)

        if cmds[i] == 7:
            grid, pos_tuple = seven(grid, pos_tuple)

        if cmds[i] == 8:
            grid, pos_tuple = eight(grid, pos_tuple)

        if cmds[i] == 9:
            grid, pos_tuple = nine(grid, pos_tuple)

        if cmds[i] == 10:
            grid, pos_tuple = ten(grid, pos_tuple)

        if cmds[i] == 11:
            grid, pos_tuple = eleven(grid, pos_tuple)

        if cmds[i] == 12:
            grid, pos_tuple = twelve(grid, pos_tuple)

    r, c = pos_tuple
    grid[r][c] = "/"

    return grid


def one(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2
    new_c = prev_c - 2 - 1
    if new_r < 0 or new_c < 0:
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)


def two(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2
    new_c = prev_c - 2 + 1
    if new_r < 0 or new_c < 0:
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def three(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2 - 1
    new_c = prev_c - 2
    if new_r < 0 or new_c < 0:
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def four(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2 + 1
    new_c = prev_c - 2
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def five(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2
    new_c = prev_c + 2 - 1
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def six(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2
    new_c = prev_c + 2 + 1
    if new_r < 0 or new_c < 0:
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def seven(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2 - 1
    new_c = prev_c + 2
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def eight(grid, position):
    prev_r, prev_c = position
    new_r = prev_r - 2 + 1
    new_c = prev_c + 2
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def nine(grid, position):
    prev_r, prev_c = position
    new_r = prev_r + 2
    new_c = prev_c - 2 -1
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def ten(grid, position):
    prev_r, prev_c = position
    new_r = prev_r + 2
    new_c = prev_c - 2 + 1
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def eleven(grid, position):
    prev_r, prev_c = position
    new_r = prev_r + 2 - 1
    new_c = prev_c - 2
    if (new_r < 0) or (new_c < 0):
        pass

    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position


def twelve(grid, position):
    prev_r, prev_c = position
    new_r = prev_r + 2 + 1
    new_c = prev_c - 2
    if (new_r < 0) or (new_c < 0):
        pass
    else:
        grid[new_r][new_c] = "*"
        position = (new_r, new_c)

    return grid, position



cmds = np.array([5,11,2,9])
result = moving_around(cmds)
print_matrix(result)
#This should print
# -------------------------------------------
# |  .  |  /  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  *  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  *  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  -  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# Out:
# |  .  |  /  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  *  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  *  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  -  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
# |  .  |  .  |  .  |  .  |  .  |  .  |  .  |
# -------------------------------------------
