# %% [markdown]
# #### Plagiarized with ID: 22101590
# #### Task 1: No issues.
# #### Task 2: a-e. No issues.
# #### f. Instead of reversing the list, the list was printed in reverse.
# #### Task 3, 4: No issues.

# %%
class Patient:
    def __init__(self, id, name, age, blood_group):
        self.id = id
        self.name = name
        self.age = age
        self.blood_group = blood_group
        self.next = None
        self.prev = None


class WRM:
    def __init__(self):
        self.dummy = Patient(None, None, None, None)
        self.dummy.next = self.dummy
        self.dummy.prev = self.dummy

    def register_patient(self, id, name, age, blood_group):
        new_patient = Patient(id, name, age, blood_group)
        new_patient.next = self.dummy
        new_patient.prev = self.dummy.prev
        self.dummy.prev.next = new_patient
        self.dummy.prev = new_patient

    def serve_patient(self):
        if self.dummy.next != self.dummy:
            patient = self.dummy.next
            self.dummy.next = patient.next
            patient.next.prev = self.dummy
            return patient.name
        else:
            return "No patients in the waiting room."

    def cancel_all(self):
        self.dummy.next = self.dummy
        self.dummy.prev = self.dummy

    def can_doctor_go_home(self):
        return self.dummy.next == self.dummy

    def show_all_patients(self):
        current = self.dummy.next
        while current != self.dummy:
            print(current.name)
            current = current.next

    def reverse_the_line(self):
        current = self.dummy.prev  # Start from the last patient
        if self.count() != 0:
            for _ in range(self.count()):
                print(current.name)  # Print the patient's name
                current = current.prev
        else :
            print("No patient left")

    def count(self):
        count = 0
        current = self.dummy.next
        while current != self.dummy:
            count += 1
            current = current.next
        return count


# Tester code
wrm = WRM()
while True:
    print("\nOptions:")
    print("1. Add Patient")
    print("2. Serve Patient")
    print("3. Show All Patients")
    print("4. Can Doctor go Home?")
    print("5. Cancel All Appointments")
    print("6. Reverse The Line")
    print("7. Quit")

    choice = input("Enter your choice: ")

    if choice == "1":
        id = int(input("Enter patient ID: "))
        name = input("Enter patient name: ")
        age = int(input("Enter patient age: "))
        blood_group = input("Enter patient blood group: ")
        wrm.register_patient(id, name, age, blood_group)
        print("Patient added successfully.")

    elif choice == "2":
        patient_name = wrm.serve_patient()
        print("Serving patient:", patient_name)

    elif choice == "3":

        wrm.show_all_patients()


    elif choice == "4":
        if wrm.can_doctor_go_home():
            print("Yes, doctor can go home.")
        else:
            print("No, there are patients waiting.")

    elif choice == "5":
        wrm.cancel_all()
        print("All appointments canceled.")

    elif choice == "6":
        wrm.reverse_the_line()


    elif choice == "7":
        print("Goodbye!")
        break
# Out:
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 1
# Enter patient ID: 33
# Enter patient name: hiya
# Enter patient age: 45
# Enter patient blood group: A+
# Patient added successfully.
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 1
# Enter patient ID: 34
# Enter patient name: saha
# Enter patient age: 34
# Enter patient blood group: B+
# Patient added successfully.
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 1
# Enter patient ID: 34
# Enter patient name: surata
# Enter patient age: 67
# Enter patient blood group: AB+
# Patient added successfully.
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 6
# surata
# saha
# hiya
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 3
# hiya
# saha
# surata
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 6
# surata
# saha
# hiya
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 2
# Serving patient: hiya
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 3
# saha
# surata
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 2
# Serving patient: saha
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 3
# surata
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 4
# No, there are patients waiting.
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 4
# No, there are patients waiting.
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 5
# All appointments canceled.
#
# Options:
# 1. Add Patient
# 2. Serve Patient
# 3. Show All Patients
# 4. Can Doctor go Home?
# 5. Cancel All Appointments
# 6. Reverse The Line
# 7. Quit
# Enter your choice: 7
# Goodbye!
