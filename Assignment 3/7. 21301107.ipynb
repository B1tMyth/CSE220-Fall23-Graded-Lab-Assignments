# %% [markdown]
# #### Task 1: Minor issues. An incorrect initialization and under the current implementation didn't handle the sorted case.
# #### Task 2: No issues.
# #### Task 3: Removes all the instances of the nodes associated with the given number instead of the its last occurence.
# #### Task 4: No issues.
# #### Task 5: No issues.
# #### Bonus Task: Didn't handle the edge case of idx==0. Also appends part of candidate line linked list in between the range instead of a single node.

# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# ***You must run this cell to install dependency***

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np

# %% [markdown]
#  ***You must Run this cell for your driver code to execute successfully***

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# Number Beads

# %%
def rotation_times(head):
  if head==None:
    return 0
  len=0
  temp=head
  while temp !=None:
    temp=temp.next
    len+=1

  temp=head
  c=0 #Should have initialized with 1 as you are comparing adajacent nodes
  while temp!=None and temp.next!=None:
    if temp.elem< temp.next.elem:
      return c
    temp=temp.next
    c+=1

  return c




print('==============Test Case 1=============')
head = createList(np.array([13,10,6,20,17]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 3
unittest.output_test(returned_value, 3)
print()

print('==============Test Case 2=============')
head = createList(np.array([6,20,17,13,10]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 1
unittest.output_test(returned_value, 1)
print()

print('==============Test Case 3=============')
head = createList(np.array([20,17,13,10,6]))
print('Rearranged Necklace: ', end = ' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times') #This should print 0
unittest.output_test(returned_value, 0)
print()
# Out:
# ==============Test Case 1=============
# Rearranged Necklace:  13-->10-->6-->20-->17
#
# Rotated: 2 times
# Wrong Answer [Your output: 2  |  Expected Output: 3]
#
# ==============Test Case 2=============
# Rearranged Necklace:  6-->20-->17-->13-->10
#
# Rotated: 0 times
# Wrong Answer [Your output: 0  |  Expected Output: 1]
#
# ==============Test Case 3=============
# Rearranged Necklace:  20-->17-->13-->10-->6
#
# Rotated: 4 times
# Wrong Answer [Your output: 4  |  Expected Output: 0]

# %% [markdown]
# Building Blocks

# %%
def check_similar(building_1, building_2):
    current_1, current_2 = building_1, building_2

    while current_1 != None and current_2 != None:
        if current_1.elem != current_2.elem:
            return "Not Similar"
        current_1 = current_1.next
        current_2 = current_2.next

    # Check if one building has more blocks than the other
    if current_1 != None:
      return "Not Similar"
    elif current_2 != None:
      return "Not Similar"
    return "Similar"


print('==============Test Case 1=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Similar'
unittest.output_test(returned_value, 'Similar')
print()

print('==============Test Case 2=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Yellow', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 3=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 4=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()
# Out:
# ==============Test Case 1=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Similar
# Accepted
#
# ==============Test Case 2=============
# Building 1:  Red-->Green-->Yellow-->Red-->Yellow-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted
#
# ==============Test Case 3=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Not Similar
# Accepted
#
# ==============Test Case 4=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted

# %% [markdown]
# Remove Compartment

# %%
def remove_compartment(head, n):
    if head is None:
        return None

    while head.elem == n:
        head = head.next
        if head is None:
            return None

    prev = head
    current = head.next

    while current is not None:
        if current.elem == n:
            prev.next = current.next
        else:
            prev = current
        current = current.next

    return head




print('==============Test Case 1=============')
head = createList(np.array([14,10,15,10,41,10,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 14-->10-->15-->10-->41-->72
print()

print('==============Test Case 2=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 15-->33-->41-->14-->72
print()

print('==============Test Case 3=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 56
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->33-->41-->14-->72
print()
# Out:
# ==============Test Case 1=============
# Original Compartment Sequence:  14-->10-->15-->10-->41-->10-->72
#
# Changed Compartment Sequence:  14-->15-->41-->72
#
#
# ==============Test Case 2=============
# Original Compartment Sequence:  10-->15-->33-->41-->14-->72
#
# Changed Compartment Sequence:  15-->33-->41-->14-->72
#
#
# ==============Test Case 3=============
# Original Compartment Sequence:  10-->15-->33-->41-->14-->72
#
# Changed Compartment Sequence:  10-->15-->33-->41-->14-->72

# %% [markdown]
# Capture the Flag

# %%
def capture_the_flag(head):
    temp = head
    result_head = None
    result_tail = None
    position = 1
    flag_linkwise = False

    while temp != None and temp != flag_linkwise: 
        if temp.elem % position == 0:
            if result_head == None:
                result_head = Node(temp.elem)
                result_tail = result_head
            else:
                new_node = Node(temp.elem)
                result_tail.next = new_node
                result_tail = new_node
        else:
            flag_linkwise = True

        position += 1
        temp = temp.next

    if flag_linkwise:
        return "Linkwise"
    else:
        return result_head



print('==============Test Case 1=============')
head = createList(np.array([11,8,21,20,5,42]))
print('Original Sequence: ', end = ' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end= ' ')
if type(new_head) == str:
  print(new_head)
else:
  printLinkedList(new_head) #This should print 11→4→7→5→1→7
print()

print('==============Test Case 2=============')
head = createList(np.array([11,8,28,20,5,42]))
print('Original Sequence: ', end = ' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end= ' ')
if type(new_head) == str:
  print(new_head) #This should print Linkwise
else:
  printLinkedList(new_head)
print()
# Out:
# ==============Test Case 1=============
# Original Sequence:  11-->8-->21-->20-->5-->42
#
# The flag is:  11-->8-->21-->20-->5-->42
#
#
# ==============Test Case 2=============
# Original Sequence:  11-->8-->28-->20-->5-->42
#
# The flag is:  Linkwise

# %% [markdown]
# Shuffle on song

# %%
def shuffle_on_song(head):
    even_head = None
    even_tail = None
    odd_head = None
    odd_tail = None
    temp = head

    while temp != None:
        if ord(temp.elem) % 2 == 0:
            if even_head == None:
                even_head = Node(temp.elem)
                even_tail = even_head
            else:
                new_node = Node(temp.elem)
                even_tail.next = new_node
                even_tail = new_node
        else:
            if odd_head == None:
                odd_head = Node(temp.elem)
                odd_tail = odd_head
            else:
                new_node = Node(temp.elem)
                odd_tail.next = new_node
                odd_tail = new_node
        temp = temp.next

    if even_head == None:
        return odd_head
    else:
        even_tail.next = odd_head
        return even_head

print('==============Test Case 1=============')
head = createList(np.array(['S','E','N','P','A','I']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_song(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->P-->S-->E-->A-->I
print()

print('==============Test Case 2=============')
head = createList(np.array(['N','I','S','H','I','N','O','Y','A']))
print('Original Play List: ', end = ' ')
printLinkedList(head)
newhead =  shuffle_on_song(head)
print('New Play List: ', end = ' ')
printLinkedList(newhead) #This should print N-->H-->N-->I-->S-->I-->O-->Y-->A
print()
# Out:
# ==============Test Case 1=============
# Original Play List:  S-->E-->N-->P-->A-->I
#
# New Play List:  N-->P-->S-->E-->A-->I
#
#
# ==============Test Case 2=============
# Original Play List:  N-->I-->S-->H-->I-->N-->O-->Y-->A
#
# New Play List:  N-->H-->N-->I-->S-->I-->O-->Y-->A

# %% [markdown]
# BONUS

# %% [markdown]
# Assemble Conga Line

# %%
def assemble_conga_line(conga_line, candidate_line, idx):
    conga_current = conga_line
    candidate_current = candidate_line
    previous_conga = None

    while conga_current is not None and idx > 0:
        previous_conga = conga_current
        conga_current = conga_current.next
        idx -= 1

    while candidate_current is not None and candidate_current.elem <= conga_current.elem:
        previous_conga.next = candidate_current
        candidate_current = candidate_current.next
        previous_conga = previous_conga.next
        previous_conga.next = conga_current

    return conga_line


print('==============Test Case 1=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([16,2,36,52,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 3
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->40-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 2=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,16,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 0
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 8-->10-->15-->34-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 3=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,12,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 2
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->41-->56-->72
printLinkedList(returned_value)
# Out:
# ==============Test Case 1=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  16-->2-->36-->52-->40-->77
#
# Changed Conga Line:  10-->15-->34-->16-->2-->36-->41-->56-->72
#
# ==============Test Case 2=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# Original candidate Line:  6-->16-->8-->36-->7-->40-->77
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\CSE220-Fall23-Graded-Lab-Assignments\Assignment 3\7. 21301107.ipynb Cell 19 line 4
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=37'>38</a> printLinkedList(candidate_line)
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=38'>39</a> insertion_idx = 0
# ---> <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=39'>40</a> returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=40'>41</a> print('Changed Conga Line: ', end = ' ') #This should print 8-->10-->15-->34-->41-->56-->72
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=41'>42</a> printLinkedList(returned_value)
#
# f:\CSE220-Fall23-Graded-Lab-Assignments\Assignment 3\7. 21301107.ipynb Cell 19 line 1
#       <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a>     idx -= 1
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a> while candidate_current is not None and candidate_current.elem <= conga_current.elem:
# ---> <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a>     previous_conga.next = candidate_current
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a>     candidate_current = candidate_current.next
#      <a href='vscode-notebook-cell:/f%3A/CSE220-Fall23-Graded-Lab-Assignments/Assignment%203/7.%2021301107.ipynb#X24sZmlsZQ%3D%3D?line=13'>14</a>     previous_conga = previous_conga.next
#
# AttributeError: 'NoneType' object has no attribute 'next'
