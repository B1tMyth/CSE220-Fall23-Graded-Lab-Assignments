# %% [markdown]
# #### Task 1: Doesn't work for a sorted list and if the maximum number is at the end.
# #### Task 2: No issues.
# #### Task 3: No issues.
# #### Task 4: No issues.
# #### Task 5: No issues.
# #### Bonus Task: Not attempted.

# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# ***You must run this cell to install dependency***

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np

# %% [markdown]
# \ ***You must Run this cell for your driver code to execute successfully***

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# Number Beads

# %%
import numpy as np

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def find_right_rotations(self):
        if not self.head:
            return 0

        current = self.head
        rotations = 0

        while current and current.next:
            if current.data > current.next.data:
                rotations += 1
            current = current.next

        return rotations

def createList(arr):
    ll = LinkedList()
    for num in arr:
        ll.append(num)
    return ll.head

def printLinkedList(head):
    current = head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")
def rotation_times(head):
    ll = LinkedList()
    ll.head = head
    rotations = ll.find_right_rotations()
    return rotations

print('==============Test Case 1=============')
head = createList(np.array([13, 10, 6, 20, 17]))
print('Rearranged Necklace: ', end=' ')
printLinkedList(head)
returned_value = rotation_times(head)
print(f'Rotated: {returned_value} times')  # This should print 3
unittest.output_test(returned_value, 3)
print()
# Out:
# ==============Test Case 1=============
# Rearranged Necklace:  17 -> 13 -> 10 -> 6 -> 20 -> None
# Rotated: 3 times

# %% [markdown]
# Building Blocks

# %%
import numpy as np

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

def check_similar(building_1, building_2):
    current_1, current_2 = building_1.head, building_2.head

    while current_1 is not None and current_2 is not None:
        if current_1.data != current_2.data:
            return "Not Similar"
        current_1 = current_1.next
        current_2 = current_2.next

    if current_1 is None and current_2 is not None:
        return "Not Similar"
    elif current_1 is not None and current_2 is None:
        return "Not Similar"
    else:
        return "Similar"

def createList(arr):
    linked_list = LinkedList()
    for item in arr:
        linked_list.append(item)
    return linked_list

def printLinkedList(head):
    current = head.head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")

# Driver code
print('==============Test Case 1=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Similar'
print()

print('==============Test Case 2=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Yellow', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
print()

print('==============Test Case 3=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
print()

print('==============Test Case 4=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
print()
# Out:
# ==============Test Case 1=============
# Building 1:  Red -> Green -> Yellow -> Red -> Blue -> Green -> None
# Building 2:  Red -> Green -> Yellow -> Red -> Blue -> Green -> None
# Similar
#
# ==============Test Case 2=============
# Building 1:  Red -> Green -> Yellow -> Red -> Yellow -> Green -> None
# Building 2:  Red -> Green -> Yellow -> Red -> Blue -> Green -> None
# Not Similar
#
# ==============Test Case 3=============
# Building 1:  Red -> Green -> Yellow -> Red -> Blue -> Green -> None
# Building 2:  Red -> Green -> Yellow -> Red -> Blue -> Green -> Blue -> None
# Not Similar
#
# ==============Test Case 4=============
# Building 1:  Red -> Green -> Yellow -> Red -> Blue -> Green -> Blue -> None
# Building 2:  Red -> Green -> Yellow -> Red -> Blue -> Green -> None
# Not Similar

# %% [markdown]
# Remove Compartment

# %%
import numpy as np

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

def createList(arr):
    linked_list = LinkedList()
    for item in arr:
        linked_list.append(item)
    return linked_list

def printLinkedList(head):
    current = head.head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")

def remove_compartment(head, n):
    current = head.head
    last_occurrence = None
    while current:
        if current.data == n:
            last_occurrence = current
        current = current.next
    if last_occurrence:
        current = head.head
        if current == last_occurrence:
            head.head = last_occurrence.next
        else:
            while current.next != last_occurrence:
                current = current.next
            current.next = last_occurrence.next
    return head

print('==============Test Case 1=============')
head = createList(np.array([14,10,15,10,41,10,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head, number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head)
print()

print('==============Test Case 2=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 10
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head, number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head)
print()

print('==============Test Case 3=============')
head = createList(np.array([10,15,33,41,14,72]))
number = 56
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head, number)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head)
print()
# Out:
# ==============Test Case 1=============
# Original Compartment Sequence:  14 -> 10 -> 15 -> 10 -> 41 -> 10 -> 72 -> None
# Changed Compartment Sequence:  14 -> 10 -> 15 -> 10 -> 41 -> 72 -> None
#
# ==============Test Case 2=============
# Original Compartment Sequence:  10 -> 15 -> 33 -> 41 -> 14 -> 72 -> None
# Changed Compartment Sequence:  15 -> 33 -> 41 -> 14 -> 72 -> None
#
# ==============Test Case 3=============
# Original Compartment Sequence:  10 -> 15 -> 33 -> 41 -> 14 -> 72 -> None
# Changed Compartment Sequence:  10 -> 15 -> 33 -> 41 -> 14 -> 72 -> None

# %% [markdown]
# Capture the Flag

# %%
import numpy as np

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

def createList(arr):
    linked_list = LinkedList()
    for item in arr:
        linked_list.append(item)
    return linked_list

def printLinkedList(head):
    current = head.head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")

def capture_the_flag(head):
    current = head.head
    position = 1
    flag_head = None
    flag_current = None

    while current is not None:
        if current.data % position == 0:
            if flag_head is None:
                flag_head = Node(current.data // position)
                flag_current = flag_head
            else:
                flag_current.next = Node(current.data // position)
                flag_current = flag_current.next
            position += 1
            current = current.next
        else:
            return "Linkwise"

    if flag_head is not None:
        return flag_head
    else:
        return "Linkwise"
print('==============Test Case 1=============')
head = createList(np.array([11, 8, 21, 20, 5, 42]))
print('Original Sequence: ', end=' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end=' ')
if isinstance(new_head, str):
    print(new_head)
else:
    current = new_head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")
print()

print('==============Test Case 2=============')
head = createList(np.array([11, 8, 28, 20, 5, 42]))
print('Original Sequence: ', end=' ')
printLinkedList(head)
new_head = capture_the_flag(head)
print('The flag is: ', end=' ')
if isinstance(new_head, str):
    print(new_head)
else:
    current = new_head
    while current:
        print(current.data, end=" -> ")
        current = current.next
    print("None")
print()
# Out:
# ==============Test Case 1=============
# Original Sequence:  11 -> 8 -> 21 -> 20 -> 5 -> 42 -> None
# The flag is:  11 -> 4 -> 7 -> 5 -> 1 -> 7 -> None
#
# ==============Test Case 2=============
# Original Sequence:  11 -> 8 -> 28 -> 20 -> 5 -> 42 -> None
# The flag is:  Linkwise

# %% [markdown]
# Shuffle on song

# %%
import numpy as np
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
def shuffle_on_song(head):
    even_head = LinkedList()
    odd_head = LinkedList()
    current = head.head
    while current:
        if ord(current.data) % 2 == 0:
            even_head.append(current.data)
        else:
            odd_head.append(current.data)
        current = current.next
    if even_head.head:
        current = even_head.head
        while current.next:
            current = current.next
        current.next = odd_head.head
        result = LinkedList()
        result.head = even_head.head
        return result
    else:
        return odd_head
def print_linked_list(linked_list):
    current = linked_list.head
    while current:
        print(current.data, end="→")
        current = current.next
    print("None")
def createList(arr):
    ll = LinkedList()
    for item in arr:
        ll.append(item)
    return ll

print('==============Test Case 1=============')
head = createList(np.array(['S','E','N','P','A','I']))
print('Original Play List: ', end=' ')
print_linked_list(head)
newhead = shuffle_on_song(head)
print('New Play List: ', end=' ')
print_linked_list(newhead)  # This should print N-->P-->S-->E-->A-->I
print()

print('==============Test Case 2=============')
head = createList(np.array(['N','I','S','H','I','N','O','Y','A']))
print('Original Play List: ', end=' ')
print_linked_list(head)
newhead = shuffle_on_song(head)
print('New Play List: ', end=' ')
print_linked_list(newhead)  # This should print N-->H-->N-->I-->S-->I-->O-->Y-->A
print()
# Out:
# ==============Test Case 1=============
# Original Play List:  S→E→N→P→A→I→None
# New Play List:  N→P→S→E→A→I→None
#
# ==============Test Case 2=============
# Original Play List:  N→I→S→H→I→N→O→Y→A→None
# New Play List:  N→H→N→I→S→I→O→Y→A→None

# %% [markdown]
# BONUS

# %% [markdown]
# Assemble Conga Line

# %%
def assemble_conga_line(conga_line, candidate_line, idx):
  #To Do
  return None


print('==============Test Case 1=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([16,2,36,52,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 3
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->40-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 2=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,16,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 0
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 8-->10-->15-->34-->41-->56-->72
printLinkedList(returned_value)

print('==============Test Case 3=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
candidate_line = createList(np.array([6,12,8,36,7,40,77]))
print('Original candidate Line: ', end = ' ')
printLinkedList(candidate_line)
insertion_idx = 2
returned_value = assemble_conga_line(conga_line, candidate_line, insertion_idx)
print('Changed Conga Line: ', end = ' ') #This should print 10-->15-->34-->41-->56-->72
printLinkedList(returned_value)
